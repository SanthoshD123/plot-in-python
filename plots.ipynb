# %% [markdown]
# <a href="https://colab.research.google.com/github/SanthoshD123/plot-in-python/blob/main/plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from google.colab import files
uploaded = files.upload()
full_health_data = pd.read_csv("exercise_dataset.csv", header=0, sep=",")

x = full_health_data["205 lb"]
y = full_health_data ["Calories per kg"]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
 return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, slope * x + intercept)
plt.ylim(ymin=0, ymax=5)
plt.xlim(xmin=0, xmax=2000)
plt.xlabel("205 lb ")
plt.ylabel ("Calories per kg ")
# Out:
#      <input type="file" id="files-53abe15b-d43c-4014-8036-95ab73ba68d5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-53abe15b-d43c-4014-8036-95ab73ba68d5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
#Generated related variable
from numpy import mean
from numpy import std
from numpy.random import randn
from numpy.random import seed
from matplotlib import pyplot
# seed random number generator
seed(1)
# prepare data
data1 = 20 * randn(1000) + 100
data2 = data1 + (10 * randn(1000) + 50)
# summarize
print('data1: mean=%.3f stdv=%.3f' % (mean(data1), std(data1)))
print('data2: mean=%.3f stdv=%.3f' % (mean(data2), std(data2)))
# plot
pyplot.scatter(data1, data2)
pyplot.show()
# Out:
# data1: mean=100.776 stdv=19.620
# data2: mean=151.050 stdv=22.358

# %%
import sklearn
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
y = pd.Series([1, 2, 3, 4, 3, 5, 4])
x = pd.Series([1, 2, 3, 4, 5, 6, 7])
correlation = y.corr(x)
print(correlation)
plt.scatter(x, y)
 # This will fit the best line into the graph
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))   (np.unique(x)), color='red')
# Out:
# 0.8603090020146067

# %%
x = range(50)
y = range(50) + np.random.randint(0,30,50)
plt.scatter(x, y)
plt.rcParams.update({'figure.figsize':(10,8), 'figure.dpi':100})
plt.title('Simple Scatter plot')
plt.xlabel('X - value')
plt.ylabel('Y - value')
plt.show()

# %%
x = range(50)
y = range(50) + np.random.randint(0,30,50)
plt.rcParams.update({'figure.figsize':(10,8), 'figure.dpi':100})
plt.scatter(x, y, c=y, cmap='Spectral')
plt.colorbar()
plt.title('Simple Scatter plot')
plt.xlabel('X - value')
plt.ylabel('Y - value')
plt.show()

# %%
from scipy.stats import norm
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
data = np.arange(1,10,0.01)
pdf = norm.pdf(data , loc = 5.3 , scale = 1 )
sb.set_style('whitegrid')
sb.lineplot(data, pdf , color = 'black')
plt.xlabel('Heights')
plt.ylabel('Probability Density')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'Probability Density')

# %%
import statistics
sample = [2.74, 1.23, 2.63, 2.22, 3, 1.98]
print("Variance of sample set is % s" , statistics.variance(sample))
# Out:
# Variance of sample set is % s 0.40924

# %%
from statistics import variance
from fractions import Fraction as fr
sample1 = (1, 2, 5, 4, 8, 9, 12)
sample2 = (-2, -4, -3, -1, -5, -6)
sample3 = (-9, -1, -0, 2, 1, 3, 4, 19)
sample4 = (fr(1, 2), fr(2, 3), fr(3, 4),fr(5, 6), fr(7, 8))
sample5 = (1.23, 1.45, 2.1, 2.2, 1.9)
print("Variance of Sample1 is ",variance(sample1))
print("Variance of Sample2 is ",variance(sample2))
print("Variance of Sample3 is ",variance(sample3))
print("Variance of Sample4 is ", variance(sample4))
print("Variance of Sample5 is ",variance(sample5))
# Out:
# Variance of Sample1 is  15.80952380952381
# Variance of Sample2 is  3.5
# Variance of Sample3 is  61.125
# Variance of Sample4 is  1/45
# Variance of Sample5 is  0.17613000000000006

# %%
import statistics
sample = (1, 1.3, 1.2, 1.9, 2.5, 2.2)
m = statistics.mean(sample)
print("Variance of Sample set is ",statistics.variance(sample, xbar = m))
# Out:
# Variance of Sample set is  0.3656666666666667

# %%
def cal_average(num):
    sum_num = 0
    for t in num:
        sum_num = sum_num + t

    avg = sum_num / len(num)
    return avg

print("The average is", cal_average([18,25,3,41,5]))
# Out:
# The average is 18.4

# %%
number_list = [45, 34, 10, 36, 12, 6, 80]
avg = sum(number_list)/len(number_list)
print("The average is ", round(avg,2))
# Out:
# The average is  31.86

# %% [markdown]
# from statistics import mean
# number_list = [45, 34, 10, 36, 12, 6, 80]
# avg = mean(number_list)
# print("The average is ", round(avg,2))

# %%
from numpy import mean
number_list = [45, 34, 10, 36, 12, 6, 80]
avg = mean(number_list)
print("The average is ", round(avg,2))
# Out:
# The average is  31.86

# %%
import numpy as np# linear algebra
import pandas as pd# data processing, CSV file I/O (e.g. pd.read_csv)
import nltk
items = ['apple', 'apple', 'kiwi', 'cabbage', 'cabbage', 'potato']
nltk.FreqDist(items)
c_items = [('F','apple'), ('F','apple'), ('F','kiwi'), ('V','cabbage'),
           ('V','cabbage'), ('V','potato') ]
cfd = nltk.ConditionalFreqDist(c_items)
cfd.conditions()
cfd.plot()
cfd['V']
# Out:
# FreqDist({'cabbage': 2, 'potato': 1})

# %%
from nltk.corpus import brown
cfd = nltk.conditionalFreqDist([ (genre, word) for genre inbrown.categories() for word in brown.words(categories=genre) ])
cfd
cfd.conditions()
cfd.tabulate(conditions=['government', 'humor', 'reviews'],samples=['leadership', 'worship', 'hardship'])
cfd.plot(conditions=['government', 'humor', 'reviews'],samples=['leadership', 'worship', 'hardship'])
cfd.tabulate(conditions=['government', 'humor', 'reviews'], samples=['leadership', 'worship', 'hardship'], cumulative =True)
news_fd = cfd['news']
news_fd.most_common(3)
news_fd['the']
